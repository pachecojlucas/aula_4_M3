# %%
import pandas as pd

# %%
table = pd.read_csv('https://raw.githubusercontent.com/diasctiago/pandas/main/leads.csv')
table.head()
# Out:
#      id              data  UF          estado          cidade status    origem
# 0  1001  16/08/2022 13:19  BA           Bahia        Salvador   lead  Facebook
# 1  1002  16/08/2022 11:05  BA           Bahia        Salvador   lead  Facebook
# 2  1003  16/08/2022 10:33  RJ  Rio de Janeiro  Rio de Janeiro   lead  Facebook
# 3  1004  16/08/2022 09:33  BA           Bahia        Salvador   lead  Facebook
# 4  1005  16/08/2022 08:56  SP       São Paulo       São Paulo   lead      Blog

# %%
table_txt = pd.read_csv('https://raw.githubusercontent.com/diasctiago/pandas/main/leads.txt', delimiter='|')
table_txt.head()
# Out:
#      id              data  UF          estado          cidade status    origem
# 0  1001  16/08/2022 13:19  BA           Bahia        Salvador   lead  Facebook
# 1  1002  16/08/2022 11:05  BA           Bahia        Salvador   lead  Facebook
# 2  1003  16/08/2022 10:33  RJ  Rio de Janeiro  Rio de Janeiro   lead  Facebook
# 3  1004  16/08/2022 09:33  BA           Bahia        Salvador   lead  Facebook
# 4  1005  16/08/2022 08:56  SP       São Paulo       São Paulo   lead      Blog

# %%
table_excel = pd.read_excel('https://github.com/diasctiago/pandas/blob/main/leads.xlsx?raw=true')
table_excel.head()
# Out:
#      id                data  UF          estado          cidade status  \
# 0  1001 2022-08-16 13:19:00  BA           Bahia        Salvador   lead
# 1  1002 2022-08-16 11:05:00  BA           Bahia        Salvador   lead
# 2  1003 2022-08-16 10:33:00  RJ  Rio de Janeiro  Rio de Janeiro   lead
# 3  1004 2022-08-16 09:33:00  BA           Bahia        Salvador   lead
# 4  1005 2022-08-16 08:56:00  SP       São Paulo       São Paulo   lead
#
#      origem
# 0  Facebook
# 1  Facebook
# 2  Facebook
# 3  Facebook
# 4      Blog

# %%
display(table_excel)
# Out:
#       id                data  UF          estado            cidade  \
# 0   1001 2022-08-16 13:19:00  BA           Bahia          Salvador
# 1   1002 2022-08-16 11:05:00  BA           Bahia          Salvador
# 2   1003 2022-08-16 10:33:00  RJ  Rio de Janeiro    Rio de Janeiro
# 3   1004 2022-08-16 09:33:00  BA           Bahia          Salvador
# 4   1005 2022-08-16 08:56:00  SP       São Paulo         São Paulo
# 5   1006 2022-08-16 08:12:00  SP       São Paulo         São Paulo
# 6   1007 2022-08-16 07:14:00  BA           Bahia          Salvador
# 7   1008 2022-08-15 23:27:00  BA           Bahia          Salvador
# 8   1009 2022-08-15 22:04:00  BA           Bahia  Lauro de Freitas
# 9   1010 2022-08-15 21:11:00  SP       São Paulo         São Paulo
# 10  1011 2022-08-15 19:53:00  BA           Bahia          Camaçari
# 11  1012 2022-08-15 17:18:00  SP       São Paulo         São Paulo
# 12  1013 2022-08-15 16:16:00  SP       São Paulo         São Paulo
# ...

# %%
https://raw.githubusercontent.com/diasctiago/pandas/1423ba4fdf53a4fb782b83d207d46804f0a0a6a1/leads.json

# %%
table_json = pd.read_json('https://raw.githubusercontent.com/diasctiago/pandas/1423ba4fdf53a4fb782b83d207d46804f0a0a6a1/leads.json')
table_json.head()
# Out:
#      id              data                                           endereço  \
# 0  1001  16/08/2022 13:19  {'UF': 'BA', 'estado': 'Bahia', 'cidade': 'Sal...
# 1  1002  16/08/2022 11:05  {'UF': 'BA', 'estado': 'Bahia', 'cidade': 'Sal...
# 2  1003  16/08/2022 10:33  {'UF': 'RJ', 'estado': 'Rio de Janeiro', 'cida...
#
#   status    origem
# 0   lead  Facebook
# 1   lead  Facebook
# 2   lead  Facebook

# %%
display(table_json)
# Out:
#      id              data                                           endereço  \
# 0  1001  16/08/2022 13:19  {'UF': 'BA', 'estado': 'Bahia', 'cidade': 'Sal...
# 1  1002  16/08/2022 11:05  {'UF': 'BA', 'estado': 'Bahia', 'cidade': 'Sal...
# 2  1003  16/08/2022 10:33  {'UF': 'RJ', 'estado': 'Rio de Janeiro', 'cida...
#
#   status    origem
# 0   lead  Facebook
# 1   lead  Facebook
# 2   lead  Facebook

# %%
from urllib import request

# %%
#normalizando os json
import json

with request.urlopen('https://raw.githubusercontent.com/diasctiago/pandas/1423ba4fdf53a4fb782b83d207d46804f0a0a6a1/leads.json') as arquivo:
    dados_json = json.load(arquivo)

# %%
dados_json_norma = pd.json_normalize(dados_json)
display(dados_json_norma)
# Out:
#      id              data status    origem endereço.UF endereço.estado  \
# 0  1001  16/08/2022 13:19   lead  Facebook          BA           Bahia
# 1  1002  16/08/2022 11:05   lead  Facebook          BA           Bahia
# 2  1003  16/08/2022 10:33   lead  Facebook          RJ  Rio de Janeiro
#
#   endereço.cidade
# 0        Salvador
# 1        Salvador
# 2  Rio de Janeiro

# %%
table_json = pd.read_json('https://raw.githubusercontent.com/diasctiago/pandas/1423ba4fdf53a4fb782b83d207d46804f0a0a6a1/leads.json')
table_json.head()

# %%
#leitura de base real
http://dados.agricultura.gov.br/dataset/420c0514-92da-4888-be85-290a0785e8a9/resource/65cce855-685e-4cfa-b3a4-2d192fc83b4e/download/rfflorestasplantadasibge2014-2016.csv

# %%
table_real= pd.read_csv('http://dados.agricultura.gov.br/dataset/420c0514-92da-4888-be85-290a0785e8a9/resource/65cce855-685e-4cfa-b3a4-2d192fc83b4e/download/rfflorestasplantadasibge2014-2016.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Input In [78], in <cell line: 1>()
# ----> 1 table_real= pd.read_csv('http://dados.agricultura.gov.br/dataset/420c0514-92da-4888-be85-290a0785e8a9/resource/65cce855-685e-4cfa-b3a4-2d192fc83b4e/download/rfflorestasplantadasibge2014-2016.csv')
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
table_real= pd.read_csv('http://dados.agricultura.gov.br/dataset/420c0514-92da-4888-be85-290a0785e8a9/resource/65cce855-685e-4cfa-b3a4-2d192fc83b4e/download/rfflorestasplantadasibge2014-2016.csv', 
                        encoding = 'Windows 1252', delimiter=';')
table_real.head()
# Out:
#    Ano (data)    País Região    Estado Estado sigla Município (Municípios)  \
# 0  31/12/2014  Brasil  Norte  Rondônia           RO  Alta Floresta D'Oeste
# 1  31/12/2015  Brasil  Norte  Rondônia           RO  Alta Floresta D'Oeste
# 2  31/12/2016  Brasil  Norte  Rondônia           RO  Alta Floresta D'Oeste
# 3  31/12/2014  Brasil  Norte  Rondônia           RO  Alta Floresta D'Oeste
# 4  31/12/2015  Brasil  Norte  Rondônia           RO  Alta Floresta D'Oeste
#
#              Município Estado Latitude Longitude Espécie florestal  Área (ha)
# 0  Alta Floresta D'Oeste (RO)   -12,47    -62,27         Eucalipto        0.0
# 1  Alta Floresta D'Oeste (RO)   -12,47    -62,27         Eucalipto        0.0
# 2  Alta Floresta D'Oeste (RO)   -12,47    -62,27         Eucalipto        0.0
# 3  Alta Floresta D'Oeste (RO)   -12,47    -62,27             Pinus        0.0
# 4  Alta Floresta D'Oeste (RO)   -12,47    -62,27             Pinus        0.0

# %%
display(table_real)
# Out:
#        Ano (data)    País        Região            Estado Estado sigla  \
# 0      31/12/2014  Brasil         Norte          Rondônia           RO
# 1      31/12/2015  Brasil         Norte          Rondônia           RO
# 2      31/12/2016  Brasil         Norte          Rondônia           RO
# 3      31/12/2014  Brasil         Norte          Rondônia           RO
# 4      31/12/2015  Brasil         Norte          Rondônia           RO
# ...           ...     ...           ...               ...          ...
# 31009  31/12/2015  Brasil  Centro Oeste  Distrito Federal           DF
# 31010  31/12/2016  Brasil  Centro Oeste  Distrito Federal           DF
# 31011  31/12/2014  Brasil  Centro Oeste  Distrito Federal           DF
# 31012  31/12/2015  Brasil  Centro Oeste  Distrito Federal           DF
# 31013  31/12/2016  Brasil  Centro Oeste  Distrito Federal           DF
#
#       Município (Municípios)            Município Estado Latitude Longitude  \
# ...

# %%
#verificando as ultimas 5 linhas
table_real.tail(10)
# Out:
#        Ano (data)    País        Região            Estado Estado sigla  \
# 31004  31/12/2016  Brasil  Centro Oeste             Goiás           GO
# 31005  31/12/2014  Brasil  Centro Oeste  Distrito Federal           DF
# 31006  31/12/2015  Brasil  Centro Oeste  Distrito Federal           DF
# 31007  31/12/2016  Brasil  Centro Oeste  Distrito Federal           DF
# 31008  31/12/2014  Brasil  Centro Oeste  Distrito Federal           DF
# 31009  31/12/2015  Brasil  Centro Oeste  Distrito Federal           DF
# 31010  31/12/2016  Brasil  Centro Oeste  Distrito Federal           DF
# 31011  31/12/2014  Brasil  Centro Oeste  Distrito Federal           DF
# 31012  31/12/2015  Brasil  Centro Oeste  Distrito Federal           DF
# 31013  31/12/2016  Brasil  Centro Oeste  Distrito Federal           DF
#
#       Município (Municípios)    Município Estado Latitude Longitude  \
# 31004          Vila Propício  Vila Propício (GO)   -15,27    -48,81
# ...

# %%
print(table_real.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31014 entries, 0 to 31013
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Ano (data)              31014 non-null  object
#  1   País                    31014 non-null  object
#  2   Região                  31014 non-null  object
#  3   Estado                  31014 non-null  object
#  4   Estado sigla            31014 non-null  object
#  5   Município (Municípios)  31014 non-null  object
#  6   Município Estado        31014 non-null  object
#  7   Latitude                31014 non-null  object
#  8   Longitude               31014 non-null  object
#  9   Espécie florestal       31014 non-null  object
#  10  Área (ha)               29658 non-null  float64
# dtypes: float64(1), object(10)
# memory usage: 2.6+ MB
# None

# %%
table_real.columns
# Out:
# Index(['Ano (data)', 'País', 'Região', 'Estado', 'Estado sigla',
#        'Município (Municípios)', 'Município Estado', 'Latitude', 'Longitude',
#        'Espécie florestal', 'Área (ha)'],
#       dtype='object')

# %%
table_real.index
# Out:
# RangeIndex(start=0, stop=31014, step=1)

# %%
table_real[['Região', 'Espécie florestal']]
# Out:
#              Região Espécie florestal
# 0             Norte         Eucalipto
# 1             Norte         Eucalipto
# 2             Norte         Eucalipto
# 3             Norte             Pinus
# 4             Norte             Pinus
# ...             ...               ...
# 31009  Centro Oeste             Pinus
# 31010  Centro Oeste             Pinus
# 31011  Centro Oeste   Outras espécies
# 31012  Centro Oeste   Outras espécies
# 31013  Centro Oeste   Outras espécies
#
# [31014 rows x 2 columns]

# %%
table_real['Espécie florestal']== 'Eucalipto'
# Out:
# 0         True
# 1         True
# 2         True
# 3        False
# 4        False
#          ...
# 31009    False
# 31010    False
# 31011    False
# 31012    False
# 31013    False
# Name: Espécie florestal, Length: 31014, dtype: bool

# %%
display(table_real[table_real['Espécie florestal']== 'Eucalipto'])
# Out:
#        Ano (data)    País        Região            Estado Estado sigla  \
# 0      31/12/2014  Brasil         Norte          Rondônia           RO
# 1      31/12/2015  Brasil         Norte          Rondônia           RO
# 2      31/12/2016  Brasil         Norte          Rondônia           RO
# 9      31/12/2014  Brasil         Norte          Rondônia           RO
# 10     31/12/2015  Brasil         Norte          Rondônia           RO
# ...           ...     ...           ...               ...          ...
# 30997  31/12/2015  Brasil  Centro Oeste             Goiás           GO
# 30998  31/12/2016  Brasil  Centro Oeste             Goiás           GO
# 31005  31/12/2014  Brasil  Centro Oeste  Distrito Federal           DF
# 31006  31/12/2015  Brasil  Centro Oeste  Distrito Federal           DF
# 31007  31/12/2016  Brasil  Centro Oeste  Distrito Federal           DF
#
#       Município (Municípios)            Município Estado Latitude Longitude  \
# ...

# %%
table_real.loc[1000]
# Out:
# Ano (data)                             31/12/2015
# País                                       Brasil
# Região                                      Norte
# Estado                                  Tocantins
# Estado sigla                                   TO
# Município (Municípios)         Lagoa do Tocantins
# Município Estado          Lagoa do Tocantins (TO)
# Latitude                                   -10,34
# Longitude                                  -47,48
# Espécie florestal                       Eucalipto
# Área (ha)                                   120.0
# Name: 1000, dtype: object

# %%
table_real.isnull().sum()
# Out:
# Ano (data)                   0
# País                         0
# Região                       0
# Estado                       0
# Estado sigla                 0
# Município (Municípios)       0
# Município Estado             0
# Latitude                     0
# Longitude                    0
# Espécie florestal            0
# Área (ha)                 1356
# dtype: int64

# %%
table_real[table_real.isnull()]
# Out:
#       Ano (data) País Região Estado Estado sigla Município (Municípios)  \
# 0            NaN  NaN    NaN    NaN          NaN                    NaN
# 1            NaN  NaN    NaN    NaN          NaN                    NaN
# 2            NaN  NaN    NaN    NaN          NaN                    NaN
# 3            NaN  NaN    NaN    NaN          NaN                    NaN
# 4            NaN  NaN    NaN    NaN          NaN                    NaN
# ...          ...  ...    ...    ...          ...                    ...
# 31009        NaN  NaN    NaN    NaN          NaN                    NaN
# 31010        NaN  NaN    NaN    NaN          NaN                    NaN
# 31011        NaN  NaN    NaN    NaN          NaN                    NaN
# 31012        NaN  NaN    NaN    NaN          NaN                    NaN
# 31013        NaN  NaN    NaN    NaN          NaN                    NaN
#
#       Município Estado Latitude Longitude Espécie florestal  Área (ha)
# ...

# %%
table_real = table.dropna(how="all", axis=1)
table_real = table.dropna(how="any", axis=0)

# %%
table_real.loc[table_real['Espécie florestal']== 'Eucalipto', ['Região', 'Estado sigla']]
# Out:
#              Região Estado sigla
# 0             Norte           RO
# 1             Norte           RO
# 2             Norte           RO
# 9             Norte           RO
# 10            Norte           RO
# ...             ...          ...
# 30997  Centro Oeste           GO
# 30998  Centro Oeste           GO
# 31005  Centro Oeste           DF
# 31006  Centro Oeste           DF
# 31007  Centro Oeste           DF
#
# [10338 rows x 2 columns]

# %%
table_real['nova coluna'] = table_real['Área (ha)']*100

# %%
display(table_real)
# Out:
#        Ano (data)    País        Região            Estado Estado sigla  \
# 0      31/12/2014  Brasil         Norte          Rondônia           RO
# 1      31/12/2015  Brasil         Norte          Rondônia           RO
# 2      31/12/2016  Brasil         Norte          Rondônia           RO
# 3      31/12/2014  Brasil         Norte          Rondônia           RO
# 4      31/12/2015  Brasil         Norte          Rondônia           RO
# ...           ...     ...           ...               ...          ...
# 31009  31/12/2015  Brasil  Centro Oeste  Distrito Federal           DF
# 31010  31/12/2016  Brasil  Centro Oeste  Distrito Federal           DF
# 31011  31/12/2014  Brasil  Centro Oeste  Distrito Federal           DF
# 31012  31/12/2015  Brasil  Centro Oeste  Distrito Federal           DF
# 31013  31/12/2016  Brasil  Centro Oeste  Distrito Federal           DF
#
#       Município (Municípios)            Município Estado Latitude Longitude  \
# ...

# %%
table_real['Nivel'] = ['Alto' if x  > 170000 else 'baixo' for x in table_real['Área (ha)']]

# %%
display(table_real)
# Out:
#        Ano (data)    País        Região            Estado Estado sigla  \
# 0      31/12/2014  Brasil         Norte          Rondônia           RO
# 1      31/12/2015  Brasil         Norte          Rondônia           RO
# 2      31/12/2016  Brasil         Norte          Rondônia           RO
# 3      31/12/2014  Brasil         Norte          Rondônia           RO
# 4      31/12/2015  Brasil         Norte          Rondônia           RO
# ...           ...     ...           ...               ...          ...
# 31009  31/12/2015  Brasil  Centro Oeste  Distrito Federal           DF
# 31010  31/12/2016  Brasil  Centro Oeste  Distrito Federal           DF
# 31011  31/12/2014  Brasil  Centro Oeste  Distrito Federal           DF
# 31012  31/12/2015  Brasil  Centro Oeste  Distrito Federal           DF
# 31013  31/12/2016  Brasil  Centro Oeste  Distrito Federal           DF
#
#       Município (Municípios)            Município Estado Latitude Longitude  \
# ...

# %%
table_real.describe()
# Out:
#            Área (ha)   nova coluna
# count   29658.000000  2.965800e+04
# mean      988.865197  9.888652e+04
# std      5477.579430  5.477579e+05
# min         0.000000  0.000000e+00
# 25%         0.000000  0.000000e+00
# 50%         0.000000  0.000000e+00
# 75%       242.000000  2.420000e+04
# max    230000.000000  2.300000e+07

# %%
round(table_real['Área (ha)'].mean(), 2)
# Out:
# 988.87

# %%
#media por estado
table_real[['Estado sigla','Área (ha)']].groupby('Estado sigla').mean()
# Out:
#                  Área (ha)
# Estado sigla
# AL               90.702899
# AP            10622.244444
# BA             2406.675000
# CE                7.956522
# DF             1224.222222
# ES             1166.813390
# GO              312.309201
# MA             1581.435185
# MG              792.108674
# MS             4191.767857
# MT              882.268987
# PA             3166.395833
# PB              311.280702
# PE              130.777778
# PI              521.699531
# PR             1397.621745
# RJ              166.957227
# RN                5.329502
# RO              216.337165
# RR             2038.176471
# RS              760.131609
# SC             1165.070498
# SE               56.982759
# SP              739.054348
# TO              649.104455

# %%
#soma por expecie
table_real[['Espécie florestal','Área (ha)' ]].groupby('Espécie florestal').sum()
# Out:
#                     Área (ha)
# Espécie florestal
# Eucalipto          21940841.0
# Outras espécies     1192967.0
# Pinus               6193956.0

# %%
table_real.groupby('Região')['Região'].count()
# Out:
# Região
# Centro Oeste     3105
# Nordeste         2727
# Norte            1413
# Sudeste         13203
# Sul             10566
# Name: Região, dtype: int64

# %%
table_real['Região'].value_counts()
# Out:
# Sudeste         13203
# Sul             10566
# Centro Oeste     3105
# Nordeste         2727
# Norte            1413
# Name: Região, dtype: int64

# %%
for col in table_real.columns:
    print(f'\###{col} ###')
    print(table_real[col].value_counts())
# Out:
# \###Ano (data) ###
# 31/12/2014    10338
# 31/12/2015    10338
# 31/12/2016    10338
# Name: Ano (data), dtype: int64
# \###País ###
# Brasil    31014
# Name: País, dtype: int64
# \###Região ###
# Sudeste         13203
# Sul             10566
# Centro Oeste     3105
# Nordeste         2727
# Norte            1413
# Name: Região, dtype: int64
# \###Estado ###
# Minas Gerais           7191
# São Paulo              4617
# Rio Grande do Sul      4419
# Paraná                 3510
# Santa Catarina         2637
# Goiás                  1404
# Mato Grosso            1008
# Bahia                   945
# Tocantins               756
# Espírito Santo          702
# Rio de Janeiro          693
# Mato Grosso do Sul      684
# Maranhão                495
# Alagoas                 369
# Rio Grande do Norte     261
# Pará                    261
# Rondônia                261
# Piauí                   225
# Sergipe                 189
# Ceará                   135
# Roraima                  90
# ...

# %%
table_real['Região'].value_counts()

# %%
table_real[table_real['Município (Municípios)'].str.contains('Salvador')]['Município (Municípios)'].unique()
# Out:
# array(['São Salvador do Tocantins', 'Salvador das Missões',
#        'Salvador do Sul'], dtype=object)

# %%
table_real['Espécie florestal'].unique()
# Out:
# array(['Eucalipto', 'Pinus', 'Outras espécies'], dtype=object)

# %%
table_real.rename(columns={'Espécie florestal': 'Gênero florestal'}, inplace= True)
display(table_real)
# Out:
#        Ano (data)    País        Região            Estado Estado sigla  \
# 0      31/12/2014  Brasil         Norte          Rondônia           RO
# 1      31/12/2015  Brasil         Norte          Rondônia           RO
# 2      31/12/2016  Brasil         Norte          Rondônia           RO
# 3      31/12/2014  Brasil         Norte          Rondônia           RO
# 4      31/12/2015  Brasil         Norte          Rondônia           RO
# ...           ...     ...           ...               ...          ...
# 31009  31/12/2015  Brasil  Centro Oeste  Distrito Federal           DF
# 31010  31/12/2016  Brasil  Centro Oeste  Distrito Federal           DF
# 31011  31/12/2014  Brasil  Centro Oeste  Distrito Federal           DF
# 31012  31/12/2015  Brasil  Centro Oeste  Distrito Federal           DF
# 31013  31/12/2016  Brasil  Centro Oeste  Distrito Federal           DF
#
#       Município (Municípios)            Município Estado Latitude Longitude  \
# ...

# %%
table_real.head()
# Out:
#    Ano (data)    País Região    Estado Estado sigla Município (Municípios)  \
# 0  31/12/2014  Brasil  Norte  Rondônia           RO  Alta Floresta D'Oeste
# 1  31/12/2015  Brasil  Norte  Rondônia           RO  Alta Floresta D'Oeste
# 2  31/12/2016  Brasil  Norte  Rondônia           RO  Alta Floresta D'Oeste
# 3  31/12/2014  Brasil  Norte  Rondônia           RO  Alta Floresta D'Oeste
# 4  31/12/2015  Brasil  Norte  Rondônia           RO  Alta Floresta D'Oeste
#
#              Município Estado Latitude Longitude Espécie florestal  Área (ha)  \
# 0  Alta Floresta D'Oeste (RO)   -12,47    -62,27         Eucalipto        0.0
# 1  Alta Floresta D'Oeste (RO)   -12,47    -62,27         Eucalipto        0.0
# 2  Alta Floresta D'Oeste (RO)   -12,47    -62,27         Eucalipto        0.0
# 3  Alta Floresta D'Oeste (RO)   -12,47    -62,27             Pinus        0.0
# 4  Alta Floresta D'Oeste (RO)   -12,47    -62,27             Pinus        0.0
#
#    nova coluna  Nivel
# 0          0.0  baixo
# ...

# %%
table_real.to_csv('florestas.csv', index = False)

# %%
table = pd.read_csv('exploracaoFlorestaPlantada.csv', delimiter=';')
display(table)
# Out:
#       UF       MUNICÍPIO NOME DETENTOR   CPF/CNPJ DETENTOR  \
# 0     AC  EPITACIOLANDIA   G. L. MAFFI  02.023.852/0001-20
# 1     AC  EPITACIOLANDIA   G. L. MAFFI  02.023.852/0001-20
# 2     AC  EPITACIOLANDIA   G. L. MAFFI  02.023.852/0001-20
# 3     AC  EPITACIOLANDIA   G. L. MAFFI  02.023.852/0001-20
# 4     AC  EPITACIOLANDIA   G. L. MAFFI  02.023.852/0001-20
# ...   ..             ...           ...                 ...
# 4365  TO    WANDERLANDIA          VFSA      019.***.***-**
# 4366  TO    WANDERLANDIA          VFSA      019.***.***-**
# 4367  TO    WANDERLANDIA          VFSA      019.***.***-**
# 4368  TO         XAMBIOA           JAP      589.***.***-**
# 4369  TO         XAMBIOA           JAP      589.***.***-**
#
#      IMÓVEL RURAL VINCULADO                          Nº CAR IMÓVEL RURAL  \
# 0        Colônia Guaraciaba  AC-1200252-BFD72C288A5247C987F4888409D180A6
# 1        Colônia Guaraciaba  AC-1200252-BFD72C288A5247C987F4888409D180A6
# ...

# %%
table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4370 entries, 0 to 4369
# Data columns (total 75 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   UF                              4370 non-null   object
#  1   MUNICÍPIO                       4366 non-null   object
#  2   NOME DETENTOR                   4365 non-null   object
#  3   CPF/CNPJ DETENTOR               4360 non-null   object
#  4   IMÓVEL RURAL VINCULADO          4370 non-null   object
#  5   Nº CAR IMÓVEL RURAL             4360 non-null   object
#  6   NOME EMPREENDIMENTO VINC        4370 non-null   object
#  7   LATITUDE PONTO CENTR EMPREEND   0 non-null      float64
#  8   LONGITUDE PONTO CENTR EMPREEND  0 non-null      float64
#  9   ATIVIDADE                       4370 non-null   object
#  10  TIPO DE EMPREENDIMENTO          4304 non-null   object
#  11  Nº CONSELHO DE CLASSE RT        2794 non-null   object
# ...

# %%
###Questão 2 - Consultar as informações básicas do dataset carregado acima da Exploração de Floresta Plantada, conforme lista abaixo:

#Quantidade de registros
#Quantidade de colunas
#Listar as colunas dos dados
#Exibir as principais informações do conjunto de dados
#Listar as colunas com dados vazios#

# %%
table[table.columns].count()
# Out:
# UF                              4370
# MUNICÍPIO                       4366
# NOME DETENTOR                   4365
# CPF/CNPJ DETENTOR               4360
# IMÓVEL RURAL VINCULADO          4370
#                                 ...
# VOL EXPLORAR UNID MEDIDA           0
# VOL EXPLORAR INI EXPLORAÇÃO     3737
# VOL EXPLORAR PERÍODO               0
# VOL EXPLORAR VOLUME             3737
# ÚLTIMA ATUALIZAÇÃO RELATÓRIO    4350
# Length: 75, dtype: int64

# %%
pd.isna(table)
# Out:
#          UF  MUNICÍPIO  NOME DETENTOR  CPF/CNPJ DETENTOR  \
# 0     False      False          False              False
# 1     False      False          False              False
# 2     False      False          False              False
# 3     False      False          False              False
# 4     False      False          False              False
# ...     ...        ...            ...                ...
# 4365  False      False          False              False
# 4366  False      False          False              False
# 4367  False      False          False              False
# 4368  False      False          False              False
# 4369  False      False          False              False
#
#       IMÓVEL RURAL VINCULADO  Nº CAR IMÓVEL RURAL  NOME EMPREENDIMENTO VINC  \
# 0                      False                False                     False
# 1                      False                False                     False
# ...

# %%
print(f' As colunas dos dados são: {table.columns}')
# Out:
#  As colunas dos dados são: Index(['UF', 'MUNICÍPIO', 'NOME DETENTOR', 'CPF/CNPJ DETENTOR',
#        'IMÓVEL RURAL VINCULADO', 'Nº CAR IMÓVEL RURAL',
#        'NOME EMPREENDIMENTO VINC', 'LATITUDE PONTO CENTR EMPREEND',
#        'LONGITUDE PONTO CENTR EMPREEND', 'ATIVIDADE', 'TIPO DE EMPREENDIMENTO',
#        'Nº CONSELHO DE CLASSE RT', 'ATIVIDADE RT', 'DATA DE CADASTRO',
#        'SITUAÇÃO DA SOLICITAÇÃO EXPLOR', 'DATA DA SITUAÇÃO',
#        'COMPETÊNCIA DA AVALIAÇÃO', 'ÓRGÃO AMBIENTAL RESP ANÁLISE',
#        'Nº PROCESSO', 'Nº PROTOCOLO', 'NOME CIENTÍFICO', 'NOME POPULAR',
#        'ÁREA EFETIVO PLANTIO', 'ESPAÇAMENTO', 'TOTAL ÁRVORES', 'VOLUME',
#        'UNIDADE MEDIDA', 'ANO CORTE', 'OBSERVAÇÃO DADOS ATIVIDADE',
#        'OPERAÇÕES EFETUADAS', 'MÊS/ANO', 'OBSERV TRATOS SILVICULTURAIS',
#        'DESBATE REALIZADO', 'NÚMERO DESBASTE', 'DESBATE COMUNICADO',
#        'DESBASTE INTENSIDADE', 'PORCENTAGEM DO DESBASTE %',
# ...

# %%
print(f'Quantidade de registros é: {table.shape[0]}; Quantidade de colunas é: {table.shape[1]}') 
print(f'As colunas dos dados são: {table.columns}')
print(f'As principais informações do conjunto de dados: {table.info()}')
display(table.isnull().sum())
# Out:
# Quantidade de registros é: 4370; Quantidade de colunas é: 75
# As colunas dos dados são: Index(['UF', 'MUNICÍPIO', 'NOME DETENTOR', 'CPF/CNPJ DETENTOR',
#        'IMÓVEL RURAL VINCULADO', 'Nº CAR IMÓVEL RURAL',
#        'NOME EMPREENDIMENTO VINC', 'LATITUDE PONTO CENTR EMPREEND',
#        'LONGITUDE PONTO CENTR EMPREEND', 'ATIVIDADE', 'TIPO DE EMPREENDIMENTO',
#        'Nº CONSELHO DE CLASSE RT', 'ATIVIDADE RT', 'DATA DE CADASTRO',
#        'SITUAÇÃO DA SOLICITAÇÃO EXPLOR', 'DATA DA SITUAÇÃO',
#        'COMPETÊNCIA DA AVALIAÇÃO', 'ÓRGÃO AMBIENTAL RESP ANÁLISE',
#        'Nº PROCESSO', 'Nº PROTOCOLO', 'NOME CIENTÍFICO', 'NOME POPULAR',
#        'ÁREA EFETIVO PLANTIO', 'ESPAÇAMENTO', 'TOTAL ÁRVORES', 'VOLUME',
#        'UNIDADE MEDIDA', 'ANO CORTE', 'OBSERVAÇÃO DADOS ATIVIDADE',
#        'OPERAÇÕES EFETUADAS', 'MÊS/ANO', 'OBSERV TRATOS SILVICULTURAIS',
#        'DESBATE REALIZADO', 'NÚMERO DESBASTE', 'DESBATE COMUNICADO',
#        'DESBASTE INTENSIDADE', 'PORCENTAGEM DO DESBASTE %',
# ...

# %%
table['UF'].unique()
# Out:
# array(['AC', 'AM', 'MA', 'MG', 'PR',
#        '81,99 m² de toras e 30,74 mst de lenha.', 'RJ', 'RO',
#        'CONSORCIADO COM PLANTAÇÃO DE CAFÉ, EM ÁREA DE USO MULTIPLO DO SOLO (ÁREA CONSOLIDADA).',
#        'RS', 'SC', 'SP', 'TO'], dtype=object)

# %%
table['CONSORCIADO COM PLANTAÇÃO DE CAFÉ, EM ÁREA DE USO MULTIPLO DO SOLO (ÁREA CONSOLIDADA)']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'CONSORCIADO COM PLANTAÇÃO DE CAFÉ, EM ÁREA DE USO MULTIPLO DO SOLO (ÁREA CONSOLIDADA)'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
table[table['Área (ha)'].isnull()]

# %%
display(table.isnull().sum())
# Out:
# UF                                 0
# MUNICÍPIO                          4
# NOME DETENTOR                      5
# CPF/CNPJ DETENTOR                 10
# IMÓVEL RURAL VINCULADO             0
#                                 ...
# VOL EXPLORAR UNID MEDIDA        4370
# VOL EXPLORAR INI EXPLORAÇÃO      633
# VOL EXPLORAR PERÍODO            4370
# VOL EXPLORAR VOLUME              633
# ÚLTIMA ATUALIZAÇÃO RELATÓRIO      20
# Length: 75, dtype: int64

# %%
table.isnull().sum()
# Out:
# UF                                 0
# MUNICÍPIO                          4
# NOME DETENTOR                      5
# CPF/CNPJ DETENTOR                 10
# IMÓVEL RURAL VINCULADO             0
#                                 ...
# VOL EXPLORAR UNID MEDIDA        4370
# VOL EXPLORAR INI EXPLORAÇÃO      633
# VOL EXPLORAR PERÍODO            4370
# VOL EXPLORAR VOLUME              633
# ÚLTIMA ATUALIZAÇÃO RELATÓRIO      20
# Length: 75, dtype: int64

# %%
for n in table.columns:
    print(n)
# Out:
# UF
# MUNICÍPIO
# NOME DETENTOR
# CPF/CNPJ DETENTOR
# IMÓVEL RURAL VINCULADO
# Nº CAR IMÓVEL RURAL
# NOME EMPREENDIMENTO VINC
# LATITUDE PONTO CENTR EMPREEND
# LONGITUDE PONTO CENTR EMPREEND
# ATIVIDADE
# TIPO DE EMPREENDIMENTO
# Nº CONSELHO DE CLASSE RT
# ATIVIDADE RT
# DATA DE CADASTRO
# SITUAÇÃO DA SOLICITAÇÃO EXPLOR
# DATA DA SITUAÇÃO
# COMPETÊNCIA DA AVALIAÇÃO
# ÓRGÃO AMBIENTAL RESP ANÁLISE
# Nº PROCESSO
# Nº PROTOCOLO
# NOME CIENTÍFICO
# NOME POPULAR
# ÁREA EFETIVO PLANTIO
# ESPAÇAMENTO
# TOTAL ÁRVORES
# VOLUME
# UNIDADE MEDIDA
# ANO CORTE
# OBSERVAÇÃO DADOS ATIVIDADE
# OPERAÇÕES EFETUADAS
# MÊS/ANO
# OBSERV TRATOS SILVICULTURAIS
# DESBATE REALIZADO
# NÚMERO DESBASTE
# DESBATE COMUNICADO
# DESBASTE INTENSIDADE
# PORCENTAGEM DO DESBASTE %
# OBSERVAÇÃO DESBASTE
# EQUAÇÃO VOLUME
# PROCESSO AMOSTRAGEM
# TIPO INVENTÁRIO
# NÍVEL PROBABILIDADE
# FORMA PARCELA
# ÁREA TOTAL PROJ
# ÁREA AMOSTRA
# PRODUTO FLORESTAL
# NOME CIENTÍFICO PF
# NOME POPULAR PF
# VOLUME(M³/ha)
# ...

# %%
y = list(table.columns)
x = list(table.isnull().sum())
unido = zip(y,x)
list(unido)
# Out:
# [('UF', 0),
#  ('MUNICÍPIO', 4),
#  ('NOME DETENTOR', 5),
#  ('CPF/CNPJ DETENTOR', 10),
#  ('IMÓVEL RURAL VINCULADO', 0),
#  ('Nº CAR IMÓVEL RURAL', 10),
#  ('NOME EMPREENDIMENTO VINC', 0),
#  ('LATITUDE PONTO CENTR EMPREEND', 4370),
#  ('LONGITUDE PONTO CENTR EMPREEND', 4370),
#  ('ATIVIDADE', 0),
#  ('TIPO DE EMPREENDIMENTO', 66),
#  ('Nº CONSELHO DE CLASSE RT', 1576),
#  ('ATIVIDADE RT', 1576),
#  ('DATA DE CADASTRO', 0),
#  ('SITUAÇÃO DA SOLICITAÇÃO EXPLOR', 0),
#  ('DATA DA SITUAÇÃO', 0),
#  ('COMPETÊNCIA DA AVALIAÇÃO', 6),
#  ('ÓRGÃO AMBIENTAL RESP ANÁLISE', 10),
#  ('Nº PROCESSO', 2839),
#  ('Nº PROTOCOLO', 3393),
#  ('NOME CIENTÍFICO', 4010),
#  ('NOME POPULAR', 4025),
#  ('ÁREA EFETIVO PLANTIO', 4010),
#  ('ESPAÇAMENTO', 4010),
#  ('TOTAL ÁRVORES', 4010),
#  ('VOLUME', 4010),
#  ('UNIDADE MEDIDA', 4010),
#  ('ANO CORTE', 4010),
#  ('OBSERVAÇÃO DADOS ATIVIDADE', 4210),
#  ('OPERAÇÕES EFETUADAS', 3822),
#  ('MÊS/ANO', 3822),
#  ('OBSERV TRATOS SILVICULTURAIS', 4153),
# ...
